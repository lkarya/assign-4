# %%
# What exactly is []?

index bracket


# In a list of values stored in a variable called spam, how would you assign the value 'hello' as the
third value? (Assume [2, 4, 6, 8, 10] are in spam.)

spam[2] = 'hello'


# What is the value of spam[int(int('3' * 2) / 11)]?

'3' * 2 is the string '33', which is passed to int() 
before divided by 11, This given 3.


# What is the value of spam[-1]?

negive index


# What is the value of spam[:2]?

['a', 'b']


# What is the value of bacon.index('cat')?
1 for true


# How does bacon.append(99) change the look of the list value in bacon?

[3.14, 'cat', 11, 'cat', True, 99]


# How does bacon.remove('cat') change the look of the list in bacon?

[3.14, 11, 'cat', True]


# What are the list concatenation and list replication operators?

The operator for list concatenation is +, while the operator for replication is *


# What is difference between the list methods append() and insert()?

While append() will add values only to the end of a list, insert() can add them anywhere in the list.


# What are two ways to remove values from a list?

The del statement and the remove() list method are two ways to remove values from a list.


# What is the difference between tuples and lists?

Lists are mutable, values added/ removed /changed. Tuples are immutable, they cannot be changed.


# How do you type a tuple value that only contains the integer 42?

(42,)


# How do you distinguish between copy.copy() and copy.deepcopy()?

The copy.copy() function will do a copy of a list, 
The copy.deepcopy() function will do a deep copy of a list.
